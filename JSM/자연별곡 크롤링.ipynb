# %%
# from urlib.parse import SplitResult
import requests
from bs4 import BeautifulSoup

# 메인 지역 검색 url
main_brunch_url = 'http://www.naturekitchen.co.kr/Store/StoreFind.aspx?Area=경기'

response = requests.get(main_brunch_url)

soup = BeautifulSoup(response.text, 'lxml')

span = soup.select('span a')

page_no_list = []
for page_number_tag in span:
    page_number_text = page_number_tag.get_text()
    page_no_list.append(page_number_text)  
page_no_list.pop()
page_max = int(page_no_list[-1])
# print(page_max)

for i in range(page_max):
    page_number = i + 1
    params = {
        
    }
    url = f'http://www.naturekitchen.co.kr/Store/StoreFind.aspx?CurrentPage={page_number}&Area=경기'
    response = requests.get(url)

    result = response.text

    soup = BeautifulSoup(result, 'lxml')

    main_menu = soup.select('table.tbl_store > tbody > tr')[2:]

    # print(main_menu)
    for td_list in main_menu:
        name = td_list.select_one('td:nth-of-type(2)').get_text(strip=True)
        location = td_list.select_one('td:nth-of-type(3)').get_text(strip=True)
        tel = td_list.select_one('td:nth-of-type(4)').get_text(strip=True)

        print(name)
        print(location)
        print(tel)
# Out:
# 평촌점
# 경기 안양시 동안구 동안로 119평촌뉴코아아울렛 10층
# 031-383-0540
# 의정부점
# 경기도 의정부시 시민로 80 센트럴타워 8층자연별곡
# 031-824-5404
# 안산뉴코아점
# 경기도 안산시 단원구 고잔2동 533 안산뉴코아 8층
# 031-507-5430
# 산본점
# 경기도 군포시 산본동 1123-1투데이몰 지하 1층
# 031-340-3854
# 서현점
# 경기도 분당구 황새울로 340 알파빌딩 4층(지하철역 4번출구 2번게이트 삼성전자 서비스센터 건물 4층)
# 031-705-0540
# 구리점
# 경기도 구리시 인창동 676-1 리맥스쇼핑타운 3층
# 031-564-0540
# 평택뉴코아점
# 경기도 평택시 비전2동 830 뉴코아아울렛9층
# 031-656-0540
# 일산대화점
# 경기도 고양시 일산서구 중앙로 1581하이투모로우 2층
# 031-923-0540
# 수원NC터미널점
# 경기도 수원시 경수대로 270NC터미널점 6층
# 031-8065-3870
# 일산뉴코아점
# 경기도 고양시 일산동구 중앙로 1206 뉴코아아울렛 9층
# 031-900-5954
# 이천NC점
# 경기 이천시 영창로 165 NC백화점 9층
# 031-8010-8654
# 오리점
# 경기도 성남시 분당구 탄천상로151번길 20애플플라자 2층
# 031-716-0540
# 수원인계점
# 수원시 팔달구 권광로 181 시네파크 5층
# 031-234-0540
# 수원망포점
# 경기도 수원시 영통구 덕영대로 1566더 판타지움 2층
# 031-202-0540
